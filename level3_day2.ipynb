# %% [markdown]
# <a href="https://colab.research.google.com/github/somineda/python/blob/py2/level3_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~!
#
# "Challenge : Chapter05 ~ 08 문제풀기"는 잘 풀어보셨나요?
#
#
# 너~~무 어려웠어요! 하는 분들을 위해 만들어봤습니다!
#
# 문제 도장깨기 !!!!!
#
# 차근차근 풀어나가면 파이썬 정복 가능입니다!
#
# 화이팅 !
#
#
# Chapter05~08의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# <br>
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>
# <br>

# %% [markdown]
# -----

# %% [markdown]
# <br>
#
# __[문제1]__
#
# 미션 부수기 챌린지
#
# 다음 미션을 차례대로 부숴주세요.
#
# <br>
#
# __미션__
# - x에 5를 할당하고, y에는 10을 할당
# - x의 값을 제곱하고, 그 값을 z에 할당
# - y의 값을 2로 나눈 후, 그 값을 a에 할당
# - a와 z를 더한 값을 b에 할당
# - b의 값이 x와 같은지 출력
# -  b와 a를 문자열로 변환하여 합친 결과를 출력
#
#
# <br>

# %%
x, y = 5, 10
z = x ** 2
a = y/2
b = a + z
print(b == x)
print(str(b) + str(a))
# Out:
# False
# 30.05.0

# %% [markdown]
# <br>
#
# __[문제2]__
#
# 변수 num에 "45.67" 이라는 문자열을 할당하고,
#
# 파이썬 나라에서 돌다리를 건너려고 합니다.
#
# 이 돌다리는 반드시 두드려 보고 건너야 합니다.
#
# 미션을 해결하면 자동으로 단단한 돌다리인지 확인 됩니다!
#
# 아래의 미션을 확인하고 돌다리를 건너주세요!
#
# <br>
#
# __미션__
# - 문자열 할당 (num)
# - 소수점 포함 숫자로 출력
# - 정수만 출력
#
# <br>

# %%
num = "45.67"
num_float = float(num)
print(num_float)

num_int = int(float(num))
print(num_int)
# Out:
# 45.67
# 45

# %% [markdown]
# <br>
#
# __[문제3]__
#
# 첫 번째 공백을 기준으로 앞부분만 추출해주세요!
#
# <br>
#
# __text = "Hello World Python"__

# %%
text = "Hello World Python"
print(text[:5])
# Out:
# Hello

# %% [markdown]
# <br>__[문제4]__
#
# 문자열 "PythonProgramming" 이 주어졌을 때, 다음 미션을 해결해주세요!
#
# <br>
#
# __미션__
# - "Python"을 출력
# - "Programming" 출력
# - "Pyg" 출력
# - "in" 출력

# %%
text = "PythonProgramming"
print(text[:6])
print(text[6:18])
# Out:
# Python
# Programming

# %% [markdown]
# __[문제5]__
#
# 해외로 편지를 보냅니다.
#
# 영어를 알파벳만 알기 때문에 아는 것만 적어 보내려고 합니다.
#
# 근데 중간에 오타가 발생해버렸네요! 문자열의 일부를 바꿔 올바르게 고쳐 주세요. (소문자)
#
# <br>
#
# __word = "abcXYZgh"__

# %%
word = "abcXYZgh"
correct = word.replace("XYZ", "xyz")
correct
# Out:
# 'abcxyzgh'
